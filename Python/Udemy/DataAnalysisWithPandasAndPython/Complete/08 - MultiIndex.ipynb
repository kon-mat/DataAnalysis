# %% [markdown]
# # MultiIndex

# %%
import pandas as pd

# %% [markdown]
# ## This Module's Dataset

# %%
# MultiIndex oznacza, że klucz składa się z kilku wartości, które pochodzą z różnych kolumn

# %%
pd.read_csv("bigmac.csv")
# Out:
#             Date        Country  Price in US Dollars
# 0     2000-04-01      Argentina             2.500000
# 1     2000-04-01      Australia             1.541667
# 2     2000-04-01         Brazil             1.648045
# 3     2000-04-01         Canada             1.938776
# 4     2000-04-01    Switzerland             3.470588
# ...          ...            ...                  ...
# 1381  2020-07-01        Ukraine             2.174714
# 1382  2020-07-01        Uruguay             4.327418
# 1383  2020-07-01  United States             5.710000
# 1384  2020-07-01        Vietnam             2.847282
# 1385  2020-07-01   South Africa             1.859349
#
# [1386 rows x 3 columns]

# %%
bigmac = pd.read_csv("bigmac.csv", parse_dates=["Date"], date_format="%Y-%m-%d")
bigmac.head()
# Out:
#         Date      Country  Price in US Dollars
# 0 2000-04-01    Argentina             2.500000
# 1 2000-04-01    Australia             1.541667
# 2 2000-04-01       Brazil             1.648045
# 3 2000-04-01       Canada             1.938776
# 4 2000-04-01  Switzerland             3.470588

# %%
bigmac.dtypes
# Out:
# Date                   datetime64[ns]
# Country                        object
# Price in US Dollars           float64
# dtype: object

# %%
bigmac.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1386 entries, 0 to 1385
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 1386 non-null   datetime64[ns]
#  1   Country              1386 non-null   object
#  2   Price in US Dollars  1386 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 32.6+ KB

# %% [markdown]
# ## Create a MultiIndex
# - A **MultiIndex** is an index with multiple levels or layers.
# - Pass the `set_index` method a list of colum names to create a multi-index **DataFrame**.
# - The order of the list's values will determine the order of the levels.
# - Alternatively, we can pass the `read_csv` function's `index_col` parameter a list of columns.

# %%
bigmac = pd.read_csv("bigmac.csv", parse_dates=["Date"], date_format="%Y-%m-%d")
bigmac.head()
# Out:
#         Date      Country  Price in US Dollars
# 0 2000-04-01    Argentina             2.500000
# 1 2000-04-01    Australia             1.541667
# 2 2000-04-01       Brazil             1.648045
# 3 2000-04-01       Canada             1.938776
# 4 2000-04-01  Switzerland             3.470588

# %%
bigmac.set_index(keys=["Date", "Country"])
# Out:
#                           Price in US Dollars
# Date       Country
# 2000-04-01 Argentina                 2.500000
#            Australia                 1.541667
#            Brazil                    1.648045
#            Canada                    1.938776
#            Switzerland               3.470588
# ...                                       ...
# 2020-07-01 Ukraine                   2.174714
#            Uruguay                   4.327418
#            United States             5.710000
#            Vietnam                   2.847282
#            South Africa              1.859349
#
# [1386 rows x 1 columns]

# %%
bigmac.set_index(keys=["Country", "Date"]).sort_index()
# Out:
#                       Price in US Dollars
# Country   Date
# Argentina 2000-04-01             2.500000
#           2001-04-01             2.500000
#           2002-04-01             0.798722
#           2003-04-01             1.423611
#           2004-05-01             1.477966
# ...                                   ...
# Vietnam   2018-07-01             2.821242
#           2019-01-01             2.801845
#           2019-07-09             2.797985
#           2020-01-14             2.847774
#           2020-07-01             2.847282
#
# [1386 rows x 1 columns]

# %%
# gdy definiujemy MultiIndex, to w pierwszej kolumnie powinny znajdować się wartości z najmniejszą ilością unikalnych wystąpień (w tym przypadku Date)
bigmac.nunique()
# Out:
# Date                     33
# Country                  57
# Price in US Dollars    1350
# dtype: int64

# %%
bigmac = bigmac.set_index(keys=["Date", "Country"])
bigmac.head()
# Out:
#                         Price in US Dollars
# Date       Country
# 2000-04-01 Argentina               2.500000
#            Australia               1.541667
#            Brazil                  1.648045
#            Canada                  1.938776
#            Switzerland             3.470588

# %%
# MultiIndex możemy również zdefiniować wewnątrz metody read_csv
bigmac = pd.read_csv("bigmac.csv", parse_dates=["Date"], date_format="%Y-%m-%d", index_col=["Date", "Country"]).sort_index()
bigmac.head()
# Out:
#                       Price in US Dollars
# Date       Country
# 2000-04-01 Argentina             2.500000
#            Australia             1.541667
#            Brazil                1.648045
#            Britain               3.002000
#            Canada                1.938776

# %%
bigmac.index
# Out:
# MultiIndex([('2000-04-01',            'Argentina'),
#             ('2000-04-01',            'Australia'),
#             ('2000-04-01',               'Brazil'),
#             ('2000-04-01',              'Britain'),
#             ('2000-04-01',               'Canada'),
#             ('2000-04-01',                'Chile'),
#             ('2000-04-01',                'China'),
#             ('2000-04-01',       'Czech Republic'),
#             ('2000-04-01',              'Denmark'),
#             ('2000-04-01',            'Euro area'),
#             ...
#             ('2020-07-01',               'Sweden'),
#             ('2020-07-01',          'Switzerland'),
#             ('2020-07-01',               'Taiwan'),
#             ('2020-07-01',             'Thailand'),
#             ('2020-07-01',               'Turkey'),
#             ('2020-07-01',              'Ukraine'),
#             ('2020-07-01', 'United Arab Emirates'),
#             ('2020-07-01',        'United States'),
#             ('2020-07-01',              'Uruguay'),
#             ('2020-07-01',              'Vietnam')],
#            names=['Date', 'Country'], length=1386)

# %%
bigmac.index.names
# Out:
# FrozenList(['Date', 'Country'])

# %%
bigmac.index[0]
# Out:
# (Timestamp('2000-04-01 00:00:00'), 'Argentina')

# %%
# tuple to lista, która nie może zostać zmieniona
type(bigmac.index[0])
# Out:
# tuple

# %% [markdown]
# ## Extract Index Level Values
# - The `get_level_values` method extracts an **Index** with the values from one level in the **MultiIndex**.
# - Invoke the `get_level_values` on the **MultiIndex**, not the **DataFrame** itself.
# - The method expects either the level's index position or its name.

# %%
bigmac = pd.read_csv("bigmac.csv", parse_dates=["Date"], date_format="%Y-%m-%d", index_col=["Date", "Country"]).sort_index()
bigmac.head()
# Out:
#                       Price in US Dollars
# Date       Country
# 2000-04-01 Argentina             2.500000
#            Australia             1.541667
#            Brazil                1.648045
#            Britain               3.002000
#            Canada                1.938776

# %%
# metoda get_level_values działa na indeksach
bigmac.index.get_level_values("Date")
# Out:
# DatetimeIndex(['2000-04-01', '2000-04-01', '2000-04-01', '2000-04-01',
#                '2000-04-01', '2000-04-01', '2000-04-01', '2000-04-01',
#                '2000-04-01', '2000-04-01',
#                ...
#                '2020-07-01', '2020-07-01', '2020-07-01', '2020-07-01',
#                '2020-07-01', '2020-07-01', '2020-07-01', '2020-07-01',
#                '2020-07-01', '2020-07-01'],
#               dtype='datetime64[ns]', name='Date', length=1386, freq=None)

# %%
# możemy wywoływać ją za pomocą id indexu
bigmac.index.get_level_values(0)
# Out:
# DatetimeIndex(['2000-04-01', '2000-04-01', '2000-04-01', '2000-04-01',
#                '2000-04-01', '2000-04-01', '2000-04-01', '2000-04-01',
#                '2000-04-01', '2000-04-01',
#                ...
#                '2020-07-01', '2020-07-01', '2020-07-01', '2020-07-01',
#                '2020-07-01', '2020-07-01', '2020-07-01', '2020-07-01',
#                '2020-07-01', '2020-07-01'],
#               dtype='datetime64[ns]', name='Date', length=1386, freq=None)

# %% [markdown]
# ## Rename Index Levels
# - Invoke the `set_names` method on the **MultiIndex** to change one or more level names.
# - Use the `names` and `level` parameter to target a nested index at a given level.
# - Alternatively, pass `names` a list of strings to overwrite *all* level names.
# - The `set_names` method returns a copy, so replace the original index to alter the **DataFrame**.

# %%
bigmac = pd.read_csv("bigmac.csv", parse_dates=["Date"], date_format="%Y-%m-%d", index_col=["Date", "Country"]).sort_index()
bigmac.head()
# Out:
#                       Price in US Dollars
# Date       Country
# 2000-04-01 Argentina             2.500000
#            Australia             1.541667
#            Brazil                1.648045
#            Britain               3.002000
#            Canada                1.938776

# %%
bigmac.index
# Out:
# MultiIndex([('2000-04-01',            'Argentina'),
#             ('2000-04-01',            'Australia'),
#             ('2000-04-01',               'Brazil'),
#             ('2000-04-01',              'Britain'),
#             ('2000-04-01',               'Canada'),
#             ('2000-04-01',                'Chile'),
#             ('2000-04-01',                'China'),
#             ('2000-04-01',       'Czech Republic'),
#             ('2000-04-01',              'Denmark'),
#             ('2000-04-01',            'Euro area'),
#             ...
#             ('2020-07-01',               'Sweden'),
#             ('2020-07-01',          'Switzerland'),
#             ('2020-07-01',               'Taiwan'),
#             ('2020-07-01',             'Thailand'),
#             ('2020-07-01',               'Turkey'),
#             ('2020-07-01',              'Ukraine'),
#             ('2020-07-01', 'United Arab Emirates'),
#             ('2020-07-01',        'United States'),
#             ('2020-07-01',              'Uruguay'),
#             ('2020-07-01',              'Vietnam')],
#            names=['Date', 'Country'], length=1386)

# %%
# nazwę indeksu możemy zmienić za pomocą set_names
# podajemy nową nazwę i numer indeksu, któremu chcemy ją nadać
bigmac.index.set_names(names="Time", level=0)
# Out:
# MultiIndex([('2000-04-01',            'Argentina'),
#             ('2000-04-01',            'Australia'),
#             ('2000-04-01',               'Brazil'),
#             ('2000-04-01',              'Britain'),
#             ('2000-04-01',               'Canada'),
#             ('2000-04-01',                'Chile'),
#             ('2000-04-01',                'China'),
#             ('2000-04-01',       'Czech Republic'),
#             ('2000-04-01',              'Denmark'),
#             ('2000-04-01',            'Euro area'),
#             ...
#             ('2020-07-01',               'Sweden'),
#             ('2020-07-01',          'Switzerland'),
#             ('2020-07-01',               'Taiwan'),
#             ('2020-07-01',             'Thailand'),
#             ('2020-07-01',               'Turkey'),
#             ('2020-07-01',              'Ukraine'),
#             ('2020-07-01', 'United Arab Emirates'),
#             ('2020-07-01',        'United States'),
#             ('2020-07-01',              'Uruguay'),
#             ('2020-07-01',              'Vietnam')],
#            names=['Time', 'Country'], length=1386)

# %%
bigmac.index.set_names(names="Country", level=1)
# Out:
# MultiIndex([('2000-04-01',            'Argentina'),
#             ('2000-04-01',            'Australia'),
#             ('2000-04-01',               'Brazil'),
#             ('2000-04-01',              'Britain'),
#             ('2000-04-01',               'Canada'),
#             ('2000-04-01',                'Chile'),
#             ('2000-04-01',                'China'),
#             ('2000-04-01',       'Czech Republic'),
#             ('2000-04-01',              'Denmark'),
#             ('2000-04-01',            'Euro area'),
#             ...
#             ('2020-07-01',               'Sweden'),
#             ('2020-07-01',          'Switzerland'),
#             ('2020-07-01',               'Taiwan'),
#             ('2020-07-01',             'Thailand'),
#             ('2020-07-01',               'Turkey'),
#             ('2020-07-01',              'Ukraine'),
#             ('2020-07-01', 'United Arab Emirates'),
#             ('2020-07-01',        'United States'),
#             ('2020-07-01',              'Uruguay'),
#             ('2020-07-01',              'Vietnam')],
#            names=['Date', 'Country'], length=1386)

# %%
# jeżeli podajemy nowe nazwy dla wszystkich indeksów, to możemy ominąć parametr level
bigmac.index.set_names(names=["Time", "Country"])
# Out:
# MultiIndex([('2000-04-01',            'Argentina'),
#             ('2000-04-01',            'Australia'),
#             ('2000-04-01',               'Brazil'),
#             ('2000-04-01',              'Britain'),
#             ('2000-04-01',               'Canada'),
#             ('2000-04-01',                'Chile'),
#             ('2000-04-01',                'China'),
#             ('2000-04-01',       'Czech Republic'),
#             ('2000-04-01',              'Denmark'),
#             ('2000-04-01',            'Euro area'),
#             ...
#             ('2020-07-01',               'Sweden'),
#             ('2020-07-01',          'Switzerland'),
#             ('2020-07-01',               'Taiwan'),
#             ('2020-07-01',             'Thailand'),
#             ('2020-07-01',               'Turkey'),
#             ('2020-07-01',              'Ukraine'),
#             ('2020-07-01', 'United Arab Emirates'),
#             ('2020-07-01',        'United States'),
#             ('2020-07-01',              'Uruguay'),
#             ('2020-07-01',              'Vietnam')],
#            names=['Time', 'Country'], length=1386)

# %%
# żeby zapisać zmiany wykorzystujemy .index
bigmac.index = bigmac.index.set_names(names=["Time", "Country"])
bigmac.head()
# Out:
#                       Price in US Dollars
# Time       Country
# 2000-04-01 Argentina             2.500000
#            Australia             1.541667
#            Brazil                1.648045
#            Britain               3.002000
#            Canada                1.938776

# %% [markdown]
# ## The sort_index Method on a MultiIndex DataFrame
# - Using the `sort_index` method, we can target all levels or specific levels of the **MultiIndex**.
# - To apply a different sort order to different levels, pass a list of Booleans.

# %%
bigmac = pd.read_csv("bigmac.csv", parse_dates=["Date"], date_format="%Y-%m-%d", index_col=["Date", "Country"])
bigmac.head()
# Out:
#                         Price in US Dollars
# Date       Country
# 2000-04-01 Argentina               2.500000
#            Australia               1.541667
#            Brazil                  1.648045
#            Canada                  1.938776
#            Switzerland             3.470588

# %%
# domyślnie metoda sort_index sortuje wszystkie indeksy po kolei
bigmac.sort_index()
# Out:
#                                  Price in US Dollars
# Date       Country
# 2000-04-01 Argentina                        2.500000
#            Australia                        1.541667
#            Brazil                           1.648045
#            Britain                          3.002000
#            Canada                           1.938776
# ...                                              ...
# 2020-07-01 Ukraine                          2.174714
#            United Arab Emirates             4.015846
#            United States                    5.710000
#            Uruguay                          4.327418
#            Vietnam                          2.847282
#
# [1386 rows x 1 columns]

# %%
bigmac.sort_index(ascending=False)
# Out:
#                                  Price in US Dollars
# Date       Country
# 2020-07-01 Vietnam                          2.847282
#            Uruguay                          4.327418
#            United States                    5.710000
#            United Arab Emirates             4.015846
#            Ukraine                          2.174714
# ...                                              ...
# 2000-04-01 Canada                           1.938776
#            Britain                          3.002000
#            Brazil                           1.648045
#            Australia                        1.541667
#            Argentina                        2.500000
#
# [1386 rows x 1 columns]

# %%
# możemy definiować warunek ascending dla poszczególnych kolumn
bigmac.sort_index(ascending=[True, False])
# Out:
#                           Price in US Dollars
# Date       Country
# 2000-04-01 United States             2.510000
#            Thailand                  1.447368
#            Taiwan                    2.287582
#            Switzerland               3.470588
#            Sweden                    2.714932
# ...                                       ...
# 2020-07-01 Brazil                    3.913528
#            Bahrain                   3.713035
#            Azerbaijan                2.324897
#            Australia                 4.578450
#            Argentina                 3.509232
#
# [1386 rows x 1 columns]

# %%
bigmac.sort_index(ascending=[False, True])
# Out:
#                           Price in US Dollars
# Date       Country
# 2020-07-01 Argentina                 3.509232
#            Australia                 4.578450
#            Azerbaijan                2.324897
#            Bahrain                   3.713035
#            Brazil                    3.913528
# ...                                       ...
# 2000-04-01 Sweden                    2.714932
#            Switzerland               3.470588
#            Taiwan                    2.287582
#            Thailand                  1.447368
#            United States             2.510000
#
# [1386 rows x 1 columns]

# %% [markdown]
# ## Extract Rows from a MultiIndex DataFrame
# - A **tuple** is an immutable list. It cannot be modified after creation.
# - Create a tuple with a comma between elements. The community convention is to wrap the elements in parentheses.
# - The `iloc` and `loc` accessors are available to extract rows by index position or label.
# - For the `loc` accessor, pass a tuple to hold the labels from the index levels.

# %%
bigmac = pd.read_csv("bigmac.csv", parse_dates=["Date"], date_format="%Y-%m-%d", index_col=["Date", "Country"]).sort_index()
bigmac.head()
# Out:
#                       Price in US Dollars
# Date       Country
# 2000-04-01 Argentina             2.500000
#            Australia             1.541667
#            Brazil                1.648045
#            Britain               3.002000
#            Canada                1.938776

# %%
# krotki (tuple) jest niezmiennym obiektem
(1, 2)
# Out:
# (1, 2)

# %%
type((1, 2))
# Out:
# tuple

# %%
bigmac.iloc[2]
# Out:
# Price in US Dollars    1.648045
# Name: (2000-04-01 00:00:00, Brazil), dtype: float64

# %%
bigmac.loc["2000-04-01"]
# Out:
#                 Price in US Dollars
# Country
# Argentina                  2.500000
# Australia                  1.541667
# Brazil                     1.648045
# Britain                    3.002000
# Canada                     1.938776
# Chile                      2.451362
# China                      1.195652
# Czech Republic             1.390537
# Denmark                    3.078358
# Euro area                  2.380800
# Hong Kong                  1.309371
# Hungary                    1.215054
# Indonesia                  1.825047
# Israel                     3.580247
# Japan                      2.773585
# Malaysia                   1.189474
# Mexico                     2.221041
# New Zealand                1.691542
# Poland                     1.279070
# Russia                     1.385965
# Singapore                  1.882353
# South Africa               1.339286
# South Korea                2.707581
# Sweden                     2.714932
# Switzerland                3.470588
# Taiwan                     2.287582
# Thailand                   1.447368
# United States              2.510000

# %%
bigmac.loc["2000-04-01", "Canada"]
# Out:
# Price in US Dollars    1.938776
# Name: (2000-04-01 00:00:00, Canada), dtype: float64

# %%
# na drugiej pozycji iloc możemy podać również nazwę kolumny, którą chcemy zwrócić dla danego indeksu
bigmac.loc["2000-04-01", "Price in US Dollars"]
# Out:
# Country
# Argentina         2.500000
# Australia         1.541667
# Brazil            1.648045
# Britain           3.002000
# Canada            1.938776
# Chile             2.451362
# China             1.195652
# Czech Republic    1.390537
# Denmark           3.078358
# Euro area         2.380800
# Hong Kong         1.309371
# Hungary           1.215054
# Indonesia         1.825047
# Israel            3.580247
# Japan             2.773585
# Malaysia          1.189474
# Mexico            2.221041
# New Zealand       1.691542
# Poland            1.279070
# Russia            1.385965
# Singapore         1.882353
# South Africa      1.339286
# South Korea       2.707581
# Sweden            2.714932
# Switzerland       3.470588
# Taiwan            2.287582
# Thailand          1.447368
# United States     2.510000
# Name: Price in US Dollars, dtype: float64

# %%
# gdy podajemy wartość dla każdego indeksu, to zalecanym sposobem jest wykorzystanie krotki
bigmac.loc[("2000-04-01", "Canada")]
# Out:
# Price in US Dollars    1.938776
# Name: (2000-04-01 00:00:00, Canada), dtype: float64

# %%
# możemy wykorzystać krotkę i zwrócić daną kolumnę
bigmac.loc[("2000-04-01", "Canada"), "Price in US Dollars"]
# Out:
# 1.93877551

# %%
bigmac.loc[[("2000-04-01", "Canada"), ("2000-04-01", "Mexico")], "Price in US Dollars"]
# Out:
# Date        Country
# 2000-04-01  Canada     1.938776
#             Mexico     2.221041
# Name: Price in US Dollars, dtype: float64

# %%
bigmac.loc[("2000-04-01", "Hungary"): ("2000-04-01", "Poland")]
# Out:
#                         Price in US Dollars
# Date       Country
# 2000-04-01 Hungary                 1.215054
#            Indonesia               1.825047
#            Israel                  3.580247
#            Japan                   2.773585
#            Malaysia                1.189474
#            Mexico                  2.221041
#            New Zealand             1.691542
#            Poland                  1.279070

# %%
start = ("2000-04-01", "Hungary")
end = ("2000-04-01", "Poland")
bigmac.loc[start:end]
# Out:
#                         Price in US Dollars
# Date       Country
# 2000-04-01 Hungary                 1.215054
#            Indonesia               1.825047
#            Israel                  3.580247
#            Japan                   2.773585
#            Malaysia                1.189474
#            Mexico                  2.221041
#            New Zealand             1.691542
#            Poland                  1.279070

# %%
bigmac.loc[("2019-07-09", "Hungary"):]
# Out:
#                                  Price in US Dollars
# Date       Country
# 2019-07-09 Hungary                          3.097667
#            India                            2.669413
#            Indonesia                        2.264685
#            Israel                           4.766311
#            Japan                            3.585712
# ...                                              ...
# 2020-07-01 Ukraine                          2.174714
#            United Arab Emirates             4.015846
#            United States                    5.710000
#            Uruguay                          4.327418
#            Vietnam                          2.847282
#
# [149 rows x 1 columns]

# %%
bigmac.loc[("2012-01-01", "Brazil"): ("2013-07-01", "Turkey")]
# Out:
#                         Price in US Dollars
# Date       Country
# 2012-01-01 Brazil                  5.678670
#            Britain                 3.823395
#            Canada                  4.632940
#            Chile                   4.050983
#            China                   2.438445
# ...                                     ...
# 2013-07-01 Sweden                  6.156874
#            Switzerland             6.719041
#            Taiwan                  2.630834
#            Thailand                2.845723
#            Turkey                  4.342384
#
# [160 rows x 1 columns]

# %%
bigmac.loc[("2012-01-01", "Brazil"): ("2013-07-01", "Turkey"), "Price in US Dollars"]
# Out:
# Date        Country
# 2012-01-01  Brazil         5.678670
#             Britain        3.823395
#             Canada         4.632940
#             Chile          4.050983
#             China          2.438445
#                              ...
# 2013-07-01  Sweden         6.156874
#             Switzerland    6.719041
#             Taiwan         2.630834
#             Thailand       2.845723
#             Turkey         4.342384
# Name: Price in US Dollars, Length: 160, dtype: float64

# %% [markdown]
# ## The transpose Method
# - The `transpose` method inverts/flips the horizontal and vertical axes of the **DataFrame**.

# %%
bigmac = pd.read_csv("bigmac.csv", parse_dates=["Date"], date_format="%Y-%m-%d", index_col=["Date", "Country"]).sort_index()
bigmac.head()
# Out:
#                       Price in US Dollars
# Date       Country
# 2000-04-01 Argentina             2.500000
#            Australia             1.541667
#            Brazil                1.648045
#            Britain               3.002000
#            Canada                1.938776

# %%
start = ("2018-01-01", "China")
end = ("2018-01-01", "Denmark")

bigmac.loc[start:end].transpose()
# Out:
# Date                2018-01-01
# Country                  China  Colombia Costa Rica Czech Republic  Denmark
# Price in US Dollars   3.171642  3.832468   4.027932       3.807779  4.93202

# %%
start = ("2018-01-01", "China")
end = ("2018-01-02", "Denmark")

bigmac.loc[start:end].transpose()
# Out:
# Date                2018-01-01                                               \
# Country                  China  Colombia Costa Rica Czech Republic  Denmark
# Price in US Dollars   3.171642  3.832468   4.027932       3.807779  4.93202
#
# Date                                                                   ...  \
# Country                 Egypt Euro area Hong Kong   Hungary     India  ...
# Price in US Dollars  1.932768  4.835787  2.621819  3.426639  2.818611  ...
#
# Date                                                                    \
# Country                Sweden Switzerland    Taiwan Thailand    Turkey
# Price in US Dollars  6.123111    6.764844  2.334788  3.72457  2.827013
#
# Date
# Country                   UAE   Ukraine United States  Uruguay   Vietnam
# Price in US Dollars  3.811598  1.636775          5.28  4.89853  2.861986
#
# [1 rows x 37 columns]

# %% [markdown]
# ## The stack Method
# - The `stack` method moves the column index to the row index.
# - Pandas will return a **MultiIndex Series**.
# - Think of it like "stacking" index levels for a **MultiIndex**.

# %%
pd.read_csv("worldstats.csv").nunique()
# Out:
# country         252
# year             56
# Population    11067
# GDP           11065
# dtype: int64

# %%
world = pd.read_csv("worldstats.csv", index_col=["year", "country"]).sort_index()
world.head()
# Out:
#                    Population           GDP
# year country
# 1960 Afghanistan    8994793.0  5.377778e+08
#      Algeria       11124892.0  2.723638e+09
#      Australia     10276477.0  1.856759e+10
#      Austria        7047539.0  6.592694e+09
#      Bahamas, The    109526.0  1.698023e+08

# %%
# metoda stack przenosi indeks kolumny do indeksu wiersza
# w tym wypadku mamy 3 poziomy indeksów
world.stack()
# Out:
# year  country
# 1960  Afghanistan  Population    8.994793e+06
#                    GDP           5.377778e+08
#       Algeria      Population    1.112489e+07
#                    GDP           2.723638e+09
#       Australia    Population    1.027648e+07
#                                      ...
# 2015  World        GDP           7.343364e+13
#       Zambia       Population    1.621177e+07
#                    GDP           2.120156e+10
#       Zimbabwe     Population    1.560275e+07
#                    GDP           1.389294e+10
# Length: 22422, dtype: float64

# %%
type(world.stack())
# Out:
# pandas.core.series.Series

# %%
world.stack().to_frame()
# Out:
#                                         0
# year country
# 1960 Afghanistan Population  8.994793e+06
#                  GDP         5.377778e+08
#      Algeria     Population  1.112489e+07
#                  GDP         2.723638e+09
#      Australia   Population  1.027648e+07
# ...                                   ...
# 2015 World       GDP         7.343364e+13
#      Zambia      Population  1.621177e+07
#                  GDP         2.120156e+10
#      Zimbabwe    Population  1.560275e+07
#                  GDP         1.389294e+10
#
# [22422 rows x 1 columns]

# %% [markdown]
# ## The unstack Method
# - The `unstack` method moves a row index to the column index (the inverse of the `stack` method).
# - By default, the `unstack` method will move the innermost index.
# - We can customize the moved index with the `level` parameter.
# - The `level` parameter accepts the level's index position or its name. It can also accept a list of positions/names.

# %%
world = pd.read_csv("worldstats.csv", index_col=["year", "country"]).sort_index().stack()
world.head()
# Out:
# year  country
# 1960  Afghanistan  Population    8.994793e+06
#                    GDP           5.377778e+08
#       Algeria      Population    1.112489e+07
#                    GDP           2.723638e+09
#       Australia    Population    1.027648e+07
# dtype: float64

# %%
# metoda unstack bez żadnych argumentów przeniesie najbardziej wewnętrzny indeks do osi kolumn
world.unstack()
# Out:
#                            Population           GDP
# year country
# 1960 Afghanistan         8.994793e+06  5.377778e+08
#      Algeria             1.112489e+07  2.723638e+09
#      Australia           1.027648e+07  1.856759e+10
#      Austria             7.047539e+06  6.592694e+09
#      Bahamas, The        1.095260e+05  1.698023e+08
# ...                               ...           ...
# 2015 Vietnam             9.170380e+07  1.935994e+11
#      West Bank and Gaza  4.422143e+06  1.267740e+10
#      World               7.346633e+09  7.343364e+13
#      Zambia              1.621177e+07  2.120156e+10
#      Zimbabwe            1.560275e+07  1.389294e+10
#
# [11211 rows x 2 columns]

# %%
world.unstack().unstack()
# Out:
#          Population                                              \
# country Afghanistan    Albania     Algeria  Andorra      Angola
# year
# 1960      8994793.0        NaN  11124892.0      NaN         NaN
# 1961      9164945.0        NaN  11404859.0      NaN         NaN
# 1962      9343772.0        NaN  11690152.0      NaN         NaN
# 1963      9531555.0        NaN  11985130.0      NaN         NaN
# 1964      9728645.0        NaN  12295973.0      NaN         NaN
# 1965      9935358.0        NaN  12626953.0      NaN         NaN
# 1966     10148841.0        NaN  12980269.0      NaN         NaN
# 1967     10368600.0        NaN  13354197.0      NaN         NaN
# 1968     10599790.0        NaN  13744383.0      NaN         NaN
# 1969     10849510.0        NaN  14144437.0      NaN         NaN
# 1970     11121097.0        NaN  14550033.0  24279.0         NaN
# 1971     11412821.0        NaN  14960111.0  25560.0         NaN
# 1972     11716896.0        NaN  15377095.0  26892.0         NaN
# 1973     12022514.0        NaN  15804428.0  28231.0         NaN
# 1997     4.303282e+09  8.529572e+09
# 1998     3.537683e+09  6.401968e+09
# 1999     3.404312e+09  6.858013e+09
# 2000     3.600683e+09  6.689958e+09
# 2001     4.094481e+09  6.777385e+09
# 2002     4.193846e+09  6.342116e+09
# 2003     4.901840e+09  5.727592e+09
# 2004     6.221078e+09  5.805598e+09
# 2005     8.331870e+09  5.755215e+09
# 2006     1.275686e+10  5.443896e+09
# 2007     1.405696e+10  5.291950e+09
# 2008     1.791086e+10  4.415703e+09
# 2009     1.532834e+10  8.157077e+09
# 2010     2.026555e+10  9.422161e+09
# 2011     2.345952e+10  1.095623e+10
# 2012     2.550306e+10  1.239272e+10
# 2013     2.804552e+10  1.349023e+10
# 2014     2.713464e+10  1.419691e+10
# 2015     2.120156e+10  1.389294e+10
#
# [56 rows x 504 columns]

# %%
world.unstack().unstack().columns
# Out:
# MultiIndex([('Population',           'Afghanistan'),
#             ('Population',               'Albania'),
#             ('Population',               'Algeria'),
#             ('Population',               'Andorra'),
#             ('Population',                'Angola'),
#             ('Population',   'Antigua and Barbuda'),
#             ('Population',            'Arab World'),
#             ('Population',             'Argentina'),
#             ('Population',               'Armenia'),
#             ('Population',                 'Aruba'),
#             ...
#             (       'GDP',            'Uzbekistan'),
#             (       'GDP',               'Vanuatu'),
#             (       'GDP',         'Venezuela, RB'),
#             (       'GDP',               'Vietnam'),
#             (       'GDP', 'Virgin Islands (U.S.)'),
#             (       'GDP',    'West Bank and Gaza'),
#             (       'GDP',                 'World'),
#             (       'GDP',           'Yemen, Rep.'),
#             (       'GDP',                'Zambia'),
#             (       'GDP',              'Zimbabwe')],
#            names=[None, 'country'], length=504)

# %%
# za pomocą level możemy zdefiniować który indeks chcemy przenieść do osi kolumn
# 0 oznacza pierwszy indeks od lewej (najbardziej zewnętrzny)
world.unstack(level=0)
# Out:
# year                            1960          1961          1962  \
# country
# Afghanistan Population  8.994793e+06  9.164945e+06  9.343772e+06
#             GDP         5.377778e+08  5.488889e+08  5.466667e+08
# Albania     Population           NaN           NaN           NaN
#             GDP                  NaN           NaN           NaN
# Algeria     Population  1.112489e+07  1.140486e+07  1.169015e+07
# ...                              ...           ...           ...
# Yemen, Rep. GDP                  NaN           NaN           NaN
# Zambia      Population  3.049586e+06  3.142848e+06  3.240664e+06
#             GDP         6.987397e+08  6.823597e+08  6.792797e+08
# Zimbabwe    Population  3.752390e+06  3.876638e+06  4.006262e+06
#             GDP         1.052990e+09  1.096647e+09  1.117602e+09
#
# year                            1963          1964          1965  \
# country
# Afghanistan Population  9.531555e+06  9.728645e+06  9.935358e+06
#             GDP         7.511112e+08  8.000000e+08  1.006667e+09
# Albania     Population           NaN           NaN           NaN
#             GDP                  NaN           NaN           NaN
# Algeria     Population  1.198513e+07  1.229597e+07  1.262695e+07
# ...                              ...           ...           ...
# Yemen, Rep. GDP                  NaN           NaN           NaN
# Zambia      Population  3.342894e+06  3.449266e+06  3.559687e+06
#             GDP         7.043397e+08  8.226397e+08  1.061200e+09
# Zimbabwe    Population  4.140804e+06  4.279561e+06  4.422132e+06
#             GDP         1.159512e+09  1.217138e+09  1.311436e+09
#
# year                            1966          1967          1968  \
# country
# Afghanistan Population  1.014884e+07  1.036860e+07  1.059979e+07
#             GDP         1.400000e+09  1.673333e+09  1.373333e+09
# Albania     Population           NaN           NaN           NaN
#             GDP                  NaN           NaN           NaN
# Algeria     Population  1.298027e+07  1.335420e+07  1.374438e+07
# ...                              ...           ...           ...
# Yemen, Rep. GDP                  NaN           NaN           NaN
# Zambia      Population  3.674088e+06  3.792864e+06  3.916928e+06
#             GDP         1.239000e+09  1.340639e+09  1.573739e+09
# Zimbabwe    Population  4.568320e+06  4.718612e+06  4.874113e+06
#             GDP         1.281750e+09  1.397002e+09  1.479600e+09
#
# year                            1969  ...          2006          2007  \
# country                               ...
# Afghanistan Population  1.084951e+07  ...  2.518362e+07  2.587754e+07
#             GDP         1.408889e+09  ...  7.057598e+09  9.843842e+09
# Albania     Population           NaN  ...  2.992547e+06  2.970017e+06
#             GDP                  NaN  ...  8.992642e+09  1.070101e+10
# Algeria     Population  1.414444e+07  ...  3.374933e+07  3.426197e+07
# ...                              ...  ...           ...           ...
# Yemen, Rep. GDP                  NaN  ...  1.908173e+10  2.563367e+10
# Zambia      Population  4.047479e+06  ...  1.238151e+07  1.273868e+07
#             GDP         1.926399e+09  ...  1.275686e+10  1.405696e+10
# Zimbabwe    Population  5.036321e+06  ...  1.312794e+07  1.329780e+07
#             GDP         1.747999e+09  ...  5.443896e+09  5.291950e+09
#
# year                            2008          2009          2010  \
# country
# Afghanistan Population  2.652874e+07  2.720729e+07  2.796221e+07
#             GDP         1.019053e+10  1.248694e+10  1.593680e+10
# Albania     Population  2.947314e+06  2.927519e+06  2.913021e+06
#             GDP         1.288135e+10  1.204421e+10  1.192695e+10
# Algeria     Population  3.481106e+07  3.540179e+07  3.603616e+07
# ...                              ...           ...           ...
# Yemen, Rep. GDP         3.039720e+10  2.845950e+10  3.090675e+10
# Zambia      Population  1.311458e+07  1.350785e+07  1.391744e+07
#             GDP         1.791086e+10  1.532834e+10  2.026555e+10
# Zimbabwe    Population  1.349546e+07  1.372100e+07  1.397390e+07
#             GDP         4.415703e+09  8.157077e+09  9.422161e+09
#
# year                            2011          2012          2013  \
# country
# Afghanistan Population  2.880917e+07  2.972680e+07  3.068250e+07
#             GDP         1.793024e+10  2.053654e+10  2.004633e+10
# Albania     Population  2.904780e+06  2.900247e+06  2.896652e+06
#             GDP         1.289087e+10  1.231978e+10  1.278103e+10
# Algeria     Population  3.671713e+07  3.743943e+07  3.818614e+07
# ...                              ...           ...           ...
# Yemen, Rep. GDP         3.107886e+10  3.207477e+10  3.595450e+10
# Zambia      Population  1.434353e+07  1.478658e+07  1.524609e+07
#             GDP         2.345952e+10  2.550306e+10  2.804552e+10
# Zimbabwe    Population  1.425559e+07  1.456548e+07  1.489809e+07
#             GDP         1.095623e+10  1.239272e+10  1.349023e+10
#
# year                            2014          2015
# country
# Afghanistan Population  3.162751e+07  3.252656e+07
#             GDP         2.005019e+10  1.919944e+10
# Albania     Population  2.893654e+06  2.889167e+06
#             GDP         1.327796e+10  1.145560e+10
# Algeria     Population  3.893433e+07  3.966652e+07
# ...                              ...           ...
# Yemen, Rep. GDP                  NaN           NaN
# Zambia      Population  1.572134e+07  1.621177e+07
#             GDP         2.713464e+10  2.120156e+10
# Zimbabwe    Population  1.524586e+07  1.560275e+07
#             GDP         1.419691e+10  1.389294e+10
#
# [504 rows x 56 columns]

# %%
world.unstack(level=1)
# Out:
# country           Afghanistan       Albania       Algeria       Andorra  \
# year
# 1960 Population  8.994793e+06           NaN  1.112489e+07           NaN
#      GDP         5.377778e+08           NaN  2.723638e+09           NaN
# 1961 Population  9.164945e+06           NaN  1.140486e+07           NaN
#      GDP         5.488889e+08           NaN  2.434767e+09           NaN
# 1962 Population  9.343772e+06           NaN  1.169015e+07           NaN
# ...                       ...           ...           ...           ...
# 2013 GDP         2.004633e+10  1.278103e+10  2.097035e+11  3.249101e+09
# 2014 Population  3.162751e+07  2.893654e+06  3.893433e+07           NaN
#      GDP         2.005019e+10  1.327796e+10  2.135185e+11           NaN
# 2015 Population  3.252656e+07  2.889167e+06  3.966652e+07           NaN
#      GDP         1.919944e+10  1.145560e+10  1.668386e+11           NaN
#
# country                Angola  Antigua and Barbuda    Arab World  \
# year
# 1960 Population           NaN                  NaN           NaN
#      GDP                  NaN                  NaN           NaN
# 1961 Population           NaN                  NaN           NaN
#      GDP                  NaN                  NaN           NaN
# 1962 Population           NaN                  NaN           NaN
# ...                       ...                  ...           ...
# 2013 GDP         1.249121e+11         1.200588e+09  2.846994e+12
# 2014 Population  2.422752e+07         9.090000e+04  3.842226e+08
#      GDP         1.267751e+11         1.220976e+09  2.873600e+12
# 2015 Population  2.502197e+07         9.181800e+04  3.920223e+08
#      GDP         1.026431e+11         1.297285e+09  2.530102e+12
#
# country             Argentina       Armenia  Aruba  ...    Uzbekistan  \
# year                                                ...
# 1960 Population           NaN           NaN    NaN  ...           NaN
#      GDP                  NaN           NaN    NaN  ...           NaN
# 1961 Population           NaN           NaN    NaN  ...           NaN
#      GDP                  NaN           NaN    NaN  ...           NaN
# 1962 Population  2.128768e+07           NaN    NaN  ...           NaN
# ...                       ...           ...    ...  ...           ...
# 2013 GDP         6.239320e+11  1.112147e+10    NaN  ...  5.679566e+10
# 2014 Population  4.298003e+07  3.006154e+06    NaN  ...  3.075770e+07
#      GDP         5.480549e+11  1.164444e+10    NaN  ...  6.313285e+10
# 2015 Population           NaN  3.017712e+06    NaN  ...  3.129950e+07
#      GDP                  NaN  1.056140e+10    NaN  ...  6.673280e+10
#
# country               Vanuatu  Venezuela, RB       Vietnam  \
# year
# 1960 Population           NaN   8.146845e+06           NaN
#      GDP                  NaN   8.607600e+09           NaN
# 1961 Population           NaN   8.461684e+06           NaN
#      GDP                  NaN   8.923367e+09           NaN
# 1962 Population           NaN   8.790590e+06           NaN
# ...                       ...            ...           ...
# 2013 GDP         8.017876e+08   3.713366e+11  1.712220e+11
# 2014 Population  2.588830e+05            NaN  9.072890e+07
#      GDP         8.149546e+08            NaN  1.862047e+11
# 2015 Population           NaN            NaN  9.170380e+07
#      GDP                  NaN            NaN  1.935994e+11
#
# country          Virgin Islands (U.S.)  West Bank and Gaza         World  \
# year
# 1960 Population                32000.0                 NaN  3.035056e+09
#      GDP                    24200000.0                 NaN  1.364643e+12
# 1961 Population                34100.0                 NaN  3.076121e+09
#      GDP                    25700000.0                 NaN  1.420440e+12
# 1962 Population                36300.0                 NaN  3.129064e+09
# ...                                ...                 ...           ...
# 2013 GDP                           NaN        1.247600e+10  7.643132e+13
# 2014 Population                    NaN        4.294682e+06  7.260780e+09
#      GDP                           NaN        1.271560e+10  7.810634e+13
# 2015 Population                    NaN        4.422143e+06  7.346633e+09
#      GDP                           NaN        1.267740e+10  7.343364e+13
#
# country           Yemen, Rep.        Zambia      Zimbabwe
# year
# 1960 Population           NaN  3.049586e+06  3.752390e+06
#      GDP                  NaN  6.987397e+08  1.052990e+09
# 1961 Population           NaN  3.142848e+06  3.876638e+06
#      GDP                  NaN  6.823597e+08  1.096647e+09
# 1962 Population           NaN  3.240664e+06  4.006262e+06
# ...                       ...           ...           ...
# 2013 GDP         3.595450e+10  2.804552e+10  1.349023e+10
# 2014 Population           NaN  1.572134e+07  1.524586e+07
#      GDP                  NaN  2.713464e+10  1.419691e+10
# 2015 Population           NaN  1.621177e+07  1.560275e+07
#      GDP                  NaN  2.120156e+10  1.389294e+10
#
# [112 rows x 252 columns]

# %%
world.unstack(level=2)
# Out:
#                            Population           GDP
# year country
# 1960 Afghanistan         8.994793e+06  5.377778e+08
#      Algeria             1.112489e+07  2.723638e+09
#      Australia           1.027648e+07  1.856759e+10
#      Austria             7.047539e+06  6.592694e+09
#      Bahamas, The        1.095260e+05  1.698023e+08
# ...                               ...           ...
# 2015 Vietnam             9.170380e+07  1.935994e+11
#      West Bank and Gaza  4.422143e+06  1.267740e+10
#      World               7.346633e+09  7.343364e+13
#      Zambia              1.621177e+07  2.120156e+10
#      Zimbabwe            1.560275e+07  1.389294e+10
#
# [11211 rows x 2 columns]

# %%
world.unstack(level="country")
# Out:
# country           Afghanistan       Albania       Algeria       Andorra  \
# year
# 1960 Population  8.994793e+06           NaN  1.112489e+07           NaN
#      GDP         5.377778e+08           NaN  2.723638e+09           NaN
# 1961 Population  9.164945e+06           NaN  1.140486e+07           NaN
#      GDP         5.488889e+08           NaN  2.434767e+09           NaN
# 1962 Population  9.343772e+06           NaN  1.169015e+07           NaN
# ...                       ...           ...           ...           ...
# 2013 GDP         2.004633e+10  1.278103e+10  2.097035e+11  3.249101e+09
# 2014 Population  3.162751e+07  2.893654e+06  3.893433e+07           NaN
#      GDP         2.005019e+10  1.327796e+10  2.135185e+11           NaN
# 2015 Population  3.252656e+07  2.889167e+06  3.966652e+07           NaN
#      GDP         1.919944e+10  1.145560e+10  1.668386e+11           NaN
#
# country                Angola  Antigua and Barbuda    Arab World  \
# year
# 1960 Population           NaN                  NaN           NaN
#      GDP                  NaN                  NaN           NaN
# 1961 Population           NaN                  NaN           NaN
#      GDP                  NaN                  NaN           NaN
# 1962 Population           NaN                  NaN           NaN
# ...                       ...                  ...           ...
# 2013 GDP         1.249121e+11         1.200588e+09  2.846994e+12
# 2014 Population  2.422752e+07         9.090000e+04  3.842226e+08
#      GDP         1.267751e+11         1.220976e+09  2.873600e+12
# 2015 Population  2.502197e+07         9.181800e+04  3.920223e+08
#      GDP         1.026431e+11         1.297285e+09  2.530102e+12
#
# country             Argentina       Armenia  Aruba  ...    Uzbekistan  \
# year                                                ...
# 1960 Population           NaN           NaN    NaN  ...           NaN
#      GDP                  NaN           NaN    NaN  ...           NaN
# 1961 Population           NaN           NaN    NaN  ...           NaN
#      GDP                  NaN           NaN    NaN  ...           NaN
# 1962 Population  2.128768e+07           NaN    NaN  ...           NaN
# ...                       ...           ...    ...  ...           ...
# 2013 GDP         6.239320e+11  1.112147e+10    NaN  ...  5.679566e+10
# 2014 Population  4.298003e+07  3.006154e+06    NaN  ...  3.075770e+07
#      GDP         5.480549e+11  1.164444e+10    NaN  ...  6.313285e+10
# 2015 Population           NaN  3.017712e+06    NaN  ...  3.129950e+07
#      GDP                  NaN  1.056140e+10    NaN  ...  6.673280e+10
#
# country               Vanuatu  Venezuela, RB       Vietnam  \
# year
# 1960 Population           NaN   8.146845e+06           NaN
#      GDP                  NaN   8.607600e+09           NaN
# 1961 Population           NaN   8.461684e+06           NaN
#      GDP                  NaN   8.923367e+09           NaN
# 1962 Population           NaN   8.790590e+06           NaN
# ...                       ...            ...           ...
# 2013 GDP         8.017876e+08   3.713366e+11  1.712220e+11
# 2014 Population  2.588830e+05            NaN  9.072890e+07
#      GDP         8.149546e+08            NaN  1.862047e+11
# 2015 Population           NaN            NaN  9.170380e+07
#      GDP                  NaN            NaN  1.935994e+11
#
# country          Virgin Islands (U.S.)  West Bank and Gaza         World  \
# year
# 1960 Population                32000.0                 NaN  3.035056e+09
#      GDP                    24200000.0                 NaN  1.364643e+12
# 1961 Population                34100.0                 NaN  3.076121e+09
#      GDP                    25700000.0                 NaN  1.420440e+12
# 1962 Population                36300.0                 NaN  3.129064e+09
# ...                                ...                 ...           ...
# 2013 GDP                           NaN        1.247600e+10  7.643132e+13
# 2014 Population                    NaN        4.294682e+06  7.260780e+09
#      GDP                           NaN        1.271560e+10  7.810634e+13
# 2015 Population                    NaN        4.422143e+06  7.346633e+09
#      GDP                           NaN        1.267740e+10  7.343364e+13
#
# country           Yemen, Rep.        Zambia      Zimbabwe
# year
# 1960 Population           NaN  3.049586e+06  3.752390e+06
#      GDP                  NaN  6.987397e+08  1.052990e+09
# 1961 Population           NaN  3.142848e+06  3.876638e+06
#      GDP                  NaN  6.823597e+08  1.096647e+09
# 1962 Population           NaN  3.240664e+06  4.006262e+06
# ...                       ...           ...           ...
# 2013 GDP         3.595450e+10  2.804552e+10  1.349023e+10
# 2014 Population           NaN  1.572134e+07  1.524586e+07
#      GDP                  NaN  2.713464e+10  1.419691e+10
# 2015 Population           NaN  1.621177e+07  1.560275e+07
#      GDP                  NaN  2.120156e+10  1.389294e+10
#
# [112 rows x 252 columns]

# %%
# możemy podawać indeks od lewej za pomocą liczb ujemnych
world.unstack(level=-1)
# Out:
#                            Population           GDP
# year country
# 1960 Afghanistan         8.994793e+06  5.377778e+08
#      Algeria             1.112489e+07  2.723638e+09
#      Australia           1.027648e+07  1.856759e+10
#      Austria             7.047539e+06  6.592694e+09
#      Bahamas, The        1.095260e+05  1.698023e+08
# ...                               ...           ...
# 2015 Vietnam             9.170380e+07  1.935994e+11
#      West Bank and Gaza  4.422143e+06  1.267740e+10
#      World               7.346633e+09  7.343364e+13
#      Zambia              1.621177e+07  2.120156e+10
#      Zimbabwe            1.560275e+07  1.389294e+10
#
# [11211 rows x 2 columns]

# %%
# możemy podać kilka indeksów i w tym przypadku podana kolejność ma znaczenie
world.unstack([1, 0])
# Out:
# country      Afghanistan       Algeria     Australia       Austria  \
# year                1960          1960          1960          1960
# Population  8.994793e+06  1.112489e+07  1.027648e+07  7.047539e+06
# GDP         5.377778e+08  2.723638e+09  1.856759e+10  6.592694e+09
#
# country     Bahamas, The    Bangladesh       Belgium        Belize  \
# year                1960          1960          1960          1960
# Population  1.095260e+05  4.820070e+07  9.153489e+06  9.206800e+04
# GDP         1.698023e+08  4.274894e+09  1.165872e+10  2.807248e+07
#
# country            Benin       Bermuda  ... United Kingdom United States  \
# year                1960          1960  ...           2015          2015
# Population  2.431620e+06  4.440000e+04  ...   6.513823e+07  3.214188e+08
# GDP         2.261956e+08  8.446665e+07  ...   2.848755e+12  1.794700e+13
#
# country    Upper middle income       Uruguay    Uzbekistan       Vietnam  \
# year                      2015          2015          2015          2015
# Population        2.550326e+09  3.431555e+06  3.129950e+07  9.170380e+07
# GDP               1.973288e+13  5.344270e+10  6.673280e+10  1.935994e+11
#
# country    West Bank and Gaza         World        Zambia      Zimbabwe
# year                     2015          2015          2015          2015
# Population       4.422143e+06  7.346633e+09  1.621177e+07  1.560275e+07
# GDP              1.267740e+10  7.343364e+13  2.120156e+10  1.389294e+10
#
# [2 rows x 11211 columns]

# %%
world.unstack(["country", "year"])
# Out:
# country      Afghanistan       Algeria     Australia       Austria  \
# year                1960          1960          1960          1960
# Population  8.994793e+06  1.112489e+07  1.027648e+07  7.047539e+06
# GDP         5.377778e+08  2.723638e+09  1.856759e+10  6.592694e+09
#
# country     Bahamas, The    Bangladesh       Belgium        Belize  \
# year                1960          1960          1960          1960
# Population  1.095260e+05  4.820070e+07  9.153489e+06  9.206800e+04
# GDP         1.698023e+08  4.274894e+09  1.165872e+10  2.807248e+07
#
# country            Benin       Bermuda  ... United Kingdom United States  \
# year                1960          1960  ...           2015          2015
# Population  2.431620e+06  4.440000e+04  ...   6.513823e+07  3.214188e+08
# GDP         2.261956e+08  8.446665e+07  ...   2.848755e+12  1.794700e+13
#
# country    Upper middle income       Uruguay    Uzbekistan       Vietnam  \
# year                      2015          2015          2015          2015
# Population        2.550326e+09  3.431555e+06  3.129950e+07  9.170380e+07
# GDP               1.973288e+13  5.344270e+10  6.673280e+10  1.935994e+11
#
# country    West Bank and Gaza         World        Zambia      Zimbabwe
# year                     2015          2015          2015          2015
# Population       4.422143e+06  7.346633e+09  1.621177e+07  1.560275e+07
# GDP              1.267740e+10  7.343364e+13  2.120156e+10  1.389294e+10
#
# [2 rows x 11211 columns]

# %% [markdown]
# ## The pivot Method
# - The `pivot` method reshapes data from a tall format to a wide format.
# - Ask yourself which direction the data will expand in if you add more entries.
# - A tall/long format expands down. A wide format expands out.
# - The `index` parameter sets the horizontal index of the pivoted **DataFrame**.
# - The `columns` parameter sets the column whose values will be the columns in the pivoted **DataFrame**.
# - The `values` parameter set the values of the pivoted **DataFrame**. Pandas will populate the correct values based on the index and column intersections.

# %%
sales = pd.read_csv("salesmen.csv")
sales
# Out:
#             Date Salesman  Revenue
# 0       1/1/2025   Sharon     7172
# 1       1/2/2025   Sharon     6362
# 2       1/3/2025   Sharon     5982
# 3       1/4/2025   Sharon     7917
# 4       1/5/2025   Sharon     7837
# ...          ...      ...      ...
# 1820  12/27/2025    Oscar      835
# 1821  12/28/2025    Oscar     3073
# 1822  12/29/2025    Oscar     6424
# 1823  12/30/2025    Oscar     7088
# 1824  12/31/2025    Oscar     8408
#
# [1825 rows x 3 columns]

# %%
#				Sharon	Oscar
#	Date
#	1/1/2025	7172	1864
#	1/2/2025	7543	7105

# w metodzie pivot podajemy trzy argumenty (indekx, kolumna która odwracamy i kolumna wartości)
sales.pivot(index="Date", columns="Salesman", values="Revenue")
# Out:
# Salesman   Alexander  Dave  Oscar  Ronald  Sharon
# Date
# 1/1/2025        4430  1864   5250    2639    7172
# 1/10/2025        301  7105   7663    8267    7543
# 1/11/2025       9489  6851   8888    1340    1053
# 1/12/2025       8719  7147   3092     279    4362
# 1/13/2025       2349  6160   6139    7540    6812
# ...              ...   ...    ...     ...     ...
# 9/5/2025        2439   211   7743    4252     992
# 9/6/2025        7585  7293   5072    1112     556
# 9/7/2025        6669  9774   5230    3608    6499
# 9/8/2025        3058  8194   7755    5762    9621
# 9/9/2025        6823  4733   5684    8922    1231
#
# [365 rows x 5 columns]

# %% [markdown]
# ## The melt Method
# - The `melt` method is the inverse of the `pivot` method.
# - It takes a 'wide' dataset and converts it to a 'tall' dataset.
# - The `melt` method is ideal when you have multiple columns storing the *same* data point.
# - Ask yourself whether the column's values are a *type* of the column header. If they're not, the data is likely stored in a wide format.
# - The `id_vars` parameters accepts the column whose values will be repeated for every column.
# - The `var_name` parameter sets the name of the new column for the varying values (the former column names).
# - The `value_name` parameter set the new name of the values column (holding the values from the original **DataFrame**).

# %%
quarters = pd.read_csv("quarters.csv")
quarters
# Out:
#     Salesman      Q1      Q2      Q3      Q4
# 0      Boris  602908  233879  354479   32704
# 1      Piers   43790  514863  297151  544493
# 2      Tommy  392668  113579  430882  247231
# 3     Travis  834663  266785  749238  570524
# 4      Cindy  580935  411379  110390  651572
# 5        Rob  656644   70803  375948  321388
# 6       Mike  486141  600753  742716  404995
# 7      Stacy  479662  742806  770712    2501
# 8  Alexandra  992673  879183   37945  293710

# %%
# do metody melt wystarczy tylko jeden parametr, czyli kolumnę której wartości mają pozostać w dotychczasowym ustawieniu
quarters.melt(id_vars="Salesman")
# Out:
#      Salesman variable   value
# 0       Boris       Q1  602908
# 1       Piers       Q1   43790
# 2       Tommy       Q1  392668
# 3      Travis       Q1  834663
# 4       Cindy       Q1  580935
# 5         Rob       Q1  656644
# 6        Mike       Q1  486141
# 7       Stacy       Q1  479662
# 8   Alexandra       Q1  992673
# 9       Boris       Q2  233879
# 10      Piers       Q2  514863
# 11      Tommy       Q2  113579
# 12     Travis       Q2  266785
# 13      Cindy       Q2  411379
# 14        Rob       Q2   70803
# 15       Mike       Q2  600753
# 16      Stacy       Q2  742806
# 17  Alexandra       Q2  879183
# 18      Boris       Q3  354479
# 19      Piers       Q3  297151
# 20      Tommy       Q3  430882
# 21     Travis       Q3  749238
# 22      Cindy       Q3  110390
# 23        Rob       Q3  375948
# 24       Mike       Q3  742716
# 25      Stacy       Q3  770712
# 26  Alexandra       Q3   37945
# 27      Boris       Q4   32704
# 28      Piers       Q4  544493
# 29      Tommy       Q4  247231
# 30     Travis       Q4  570524
# 31      Cindy       Q4  651572
# 32        Rob       Q4  321388
# 33       Mike       Q4  404995
# 34      Stacy       Q4    2501
# 35  Alexandra       Q4  293710

# %%
# możemy ustawić określone nazwy dla kolumn
quarters.melt(id_vars="Salesman", var_name="Quarter", value_name="Revenue")
# Out:
#      Salesman Quarter  Revenue
# 0       Boris      Q1   602908
# 1       Piers      Q1    43790
# 2       Tommy      Q1   392668
# 3      Travis      Q1   834663
# 4       Cindy      Q1   580935
# 5         Rob      Q1   656644
# 6        Mike      Q1   486141
# 7       Stacy      Q1   479662
# 8   Alexandra      Q1   992673
# 9       Boris      Q2   233879
# 10      Piers      Q2   514863
# 11      Tommy      Q2   113579
# 12     Travis      Q2   266785
# 13      Cindy      Q2   411379
# 14        Rob      Q2    70803
# 15       Mike      Q2   600753
# 16      Stacy      Q2   742806
# 17  Alexandra      Q2   879183
# 18      Boris      Q3   354479
# 19      Piers      Q3   297151
# 20      Tommy      Q3   430882
# 21     Travis      Q3   749238
# 22      Cindy      Q3   110390
# 23        Rob      Q3   375948
# 24       Mike      Q3   742716
# 25      Stacy      Q3   770712
# 26  Alexandra      Q3    37945
# 27      Boris      Q4    32704
# 28      Piers      Q4   544493
# 29      Tommy      Q4   247231
# 30     Travis      Q4   570524
# 31      Cindy      Q4   651572
# 32        Rob      Q4   321388
# 33       Mike      Q4   404995
# 34      Stacy      Q4     2501
# 35  Alexandra      Q4   293710

# %% [markdown]
# ## The pivot_table Method
# - The `pivot_table` method operates similarly to the Pivot Table feature in Excel.
# - A pivot table is a table whose values are aggregations of groups of values from another table.
# - The `values` parameter accepts the numeric column whose values will be aggregated.
# - The `aggfunc` parameter declares the aggregation function (the default is mean/average).
# - The `index` parameter sets the index labels of the pivot table. MultiIndexes are permitted.
# - The `columns` parameter sets the column labels of the pivot table. MultiIndexes are permitted.

# %%
foods = pd.read_csv("foods.csv")
foods.head()
# Out:
#   First Name  Gender          City Frequency       Item  Spend
# 0      Wanda  Female      Stamford    Weekly     Burger  15.66
# 1       Eric    Male      Stamford     Daily    Chalupa  10.56
# 2    Charles    Male      New York     Never      Sushi  42.14
# 3       Anna  Female  Philadelphia      Once  Ice Cream  11.01
# 4    Deborah  Female  Philadelphia     Daily    Chalupa  23.49

# %%
# domyślnie funkcją agregacyjną, którą używa pandas jest średnia
foods.pivot_table(values="Spend", index="Gender")
# Out:
#             Spend
# Gender
# Female  50.709629
# Male    49.397623

# %%
foods.pivot_table(values="Spend", index="Gender", aggfunc="sum")
# Out:
#            Spend
# Gender
# Female  25963.33
# Male    24106.04

# %%
foods.pivot_table(values="Spend", index="Item", aggfunc="sum")
# Out:
#              Spend
# Item
# Burger     7765.73
# Burrito    8270.44
# Chalupa    7644.52
# Donut      8758.76
# Ice Cream  8886.99
# Sushi      8742.93

# %%
foods.pivot_table(values="Spend", index=["Gender", "Item"], aggfunc="sum")
# Out:
#                     Spend
# Gender Item
# Female Burger     4094.30
#        Burrito    4257.82
#        Chalupa    4152.26
#        Donut      4743.00
#        Ice Cream  4032.87
#        Sushi      4683.08
# Male   Burger     3671.43
#        Burrito    4012.62
#        Chalupa    3492.26
#        Donut      4015.76
#        Ice Cream  4854.12
#        Sushi      4059.85

# %%
foods.pivot_table(values="Spend", index=["Gender", "Item"], columns="City", aggfunc="sum")
# Out:
# City              New York  Philadelphia  Stamford
# Gender Item
# Female Burger      1239.04       1639.24   1216.02
#        Burrito      978.95       1458.76   1820.11
#        Chalupa      876.58       1673.33   1602.35
#        Donut       1446.78       1639.26   1656.96
#        Ice Cream   1521.62       1479.22   1032.03
#        Sushi       1480.29       1742.88   1459.91
# Male   Burger      1294.09        938.18   1439.16
#        Burrito     1399.40       1312.93   1300.29
#        Chalupa     1227.77       1114.23   1150.26
#        Donut       1345.27       1249.36   1421.13
#        Ice Cream   1603.63       2191.27   1059.22
#        Sushi       1396.15       1395.88   1267.82

# %%
foods.pivot_table(values="Spend", index="Item", columns=["Gender", "City"], aggfunc="sum")
# Out:
# Gender      Female                           Male
# City      New York Philadelphia Stamford New York Philadelphia Stamford
# Item
# Burger     1239.04      1639.24  1216.02  1294.09       938.18  1439.16
# Burrito     978.95      1458.76  1820.11  1399.40      1312.93  1300.29
# Chalupa     876.58      1673.33  1602.35  1227.77      1114.23  1150.26
# Donut      1446.78      1639.26  1656.96  1345.27      1249.36  1421.13
# Ice Cream  1521.62      1479.22  1032.03  1603.63      2191.27  1059.22
# Sushi      1480.29      1742.88  1459.91  1396.15      1395.88  1267.82

# %%
# rodzaje agregacji:
# sum, mean, count, max, min

foods.pivot_table(values="Spend", index="Item", columns=["Gender", "City"], aggfunc="count")
# Out:
# Gender      Female                           Male
# City      New York Philadelphia Stamford New York Philadelphia Stamford
# Item
# Burger          24           31       27       22           21       31
# Burrito         23           28       34       25           30       28
# Chalupa         19           32       25       25           23       23
# Donut           31           30       34       30           33       29
# Ice Cream       27           32       22       29           41       25
# Sushi           31           30       32       27           28       18
